#        -8.26160423e-03, -4.69308123e-02, -4.30577016e-03,  4.33135740e-02,
#         5.17547317e-02,  3.81230153e-02, -7.53307119e-02, -6.32745773e-02,
#        -2.16027703e-02,  1.25859082e-02,  2.81485934e-02,  4.44088466e-02,
#        -5.24927191e-02, -3.43524516e-02,  6.44143298e-02, -9.25666280e-03,
#         7.19451457e-02,  6.03718916e-03,  6.99468609e-03, -9.66396928e-02,
#        -1.59735251e-02, -2.06198804e-02,  4.98580262e-02, -5.53149022e-02,
#         8.93838238e-03,  2.22797580e-02,  1.53921749e-02,  1.28869535e-02,
#         2.11946629e-02, -1.07240006e-02, -6.75556436e-02,  1.23539202e-01,
#        -1.34003162e-01, -7.63724148e-02,  1.77290458e-02,  9.88650136e-03,
#        -3.39308381e-02,  4.85359598e-03,  1.10132605e-01, -4.93807979e-02,
#         4.04094718e-02,  2.86941379e-02,  3.72145288e-02,  3.02937701e-02,
#        -2.32057851e-02,  4.59896438e-02,  5.34617677e-02, -3.56634222e-02,
#        -3.56193930e-02, -9.76229012e-02, -1.45934761e-01, -3.36031094e-02,
#         8.79986957e-02, -9.36759450e-03,  9.57541391e-02,  8.50735232e-02,
#        -2.03977618e-02,  4.05356139e-02, -7.45057082e-03, -3.83673012e-02,
#         8.83462429e-02,  3.42343524e-02, -6.70460835e-02, -1.83787607e-02],
#       dtype=float32)

# %% [markdown]
# ## Using embeddings to find textual similarity

# %%
# Two lists of sentences
sentences1 = [
    "I am currently learning Generative AI",
]

sentences2 = [
    "Generative AI is so cool",
    "Machine Learning is used to solve tabular problems mostly",
]

# Compute embeddings for both lists
embeddings1 = model.encode(sentences1)
embeddings2 = model.encode(sentences2)

# Compute cosine similarities
similarities = model.similarity(embeddings1, embeddings2)

# Output the pairs with their score
for idx_i, sentence1 in enumerate(sentences1):
    print(sentence1)
    for idx_j, sentence2 in enumerate(sentences2):
        print(f" - {sentence2: <30}: {similarities[idx_i][idx_j]:.4f}")
# Out:
# I am currently learning Generative AI
#  - Generative AI is so cool      : 0.7465
#  - Machine Learning is used to solve tabular problems mostly: 0.3403

# %% [markdown]
# ## Using embeddings for Image Search (change with your images)

# %%
from PIL import Image

# Load CLIP model
model = SentenceTransformer("clip-ViT-B-32")
# Out:
# modules.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/1.91k [00:00<?, ?B/s]
# 0_CLIPModel/tokenizer_config.json:   0%|          | 0.00/604 [00:00<?, ?B/s]
# 0_CLIPModel/config.json:   0%|          | 0.00/4.03k [00:00<?, ?B/s]
# 0_CLIPModel/preprocessor_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# 0_CLIPModel/special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]
# 0_CLIPModel/vocab.json:   0%|          | 0.00/961k [00:00<?, ?B/s]
# 0_CLIPModel/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/605M [00:00<?, ?B/s]

# %%
image = Image.open("/content/beach-2178747_640.webp")
resized_image = image
resized_image
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=425x640>

# %%
# Encode an image:
img_emb = model.encode(resized_image)

# Encode text descriptions
text_emb = model.encode(
    ["Tree near the beach", "An animal running in the jungle","Tall standing tree"]
)

# Compute similarities
similarity_scores = model.similarity(img_emb, text_emb)
print(similarity_scores)
# Out:
# tensor([[0.2534, 0.2073, 0.2323]])

# %% [markdown]
# The similarity scores are too low but still Tree near the beach gets the highest similarity. Lets see what can increase the similarity? Maybe the change in text..

# %%
# Encode text descriptions
text_emb = model.encode(
    ["Tree near the beach showing the green leaves and in the background flowing the blue ocean with an green brownish beach"]
)
# Compute similarities
similarity_scores = model.similarity(img_emb, text_emb)
print(similarity_scores)
# Out:
# tensor([[0.2948]])
